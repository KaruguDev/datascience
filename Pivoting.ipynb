# %% [markdown]
# # Pivoting
#
# ## Deriving a new table from a existing one
#
# * Specify index or indices to pivot on
# * data is reshaped based on column values

# %%
import pandas as pd
import os

# %%
#file path
cwd = os.getcwd()

#file
file = cwd + '/data_source/vgsales.csv'

#Dataframe
vgs = pd.read_csv(file)
vgs.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsp = pd.pivot_table(vgs, index=['Rank','Name', 'Year'])
vgsp.head()
# Out:
#                                       EU_Sales  Global_Sales  JP_Sales  \
# Rank Name                     Year
# 1    Wii Sports               2006.0     29.02         82.74      3.77
# 2    Super Mario Bros.        1985.0      3.58         40.24      6.81
# 3    Mario Kart Wii           2008.0     12.88         35.82      3.79
# 4    Wii Sports Resort        2009.0     11.01         33.00      3.28
# 5    Pokemon Red/Pokemon Blue 1996.0      8.89         31.37     10.22
#
#                                       NA_Sales  Other_Sales
# Rank Name                     Year
# 1    Wii Sports               2006.0     41.49         8.46
# 2    Super Mario Bros.        1985.0     29.08         0.77
# 3    Mario Kart Wii           2008.0     15.85         3.31
# 4    Wii Sports Resort        2009.0     15.75         2.96
# 5    Pokemon Red/Pokemon Blue 1996.0     11.27         1.00

# %%
vgsp2 = pd.pivot_table(vgs, index=['Rank','Name', 'Year'], values=['EU_Sales', 'JP_Sales'])
vgsp2.head()
# Out:
#                                       EU_Sales  JP_Sales
# Rank Name                     Year
# 1    Wii Sports               2006.0     29.02      3.77
# 2    Super Mario Bros.        1985.0      3.58      6.81
# 3    Mario Kart Wii           2008.0     12.88      3.79
# 4    Wii Sports Resort        2009.0     11.01      3.28
# 5    Pokemon Red/Pokemon Blue 1996.0      8.89     10.22
