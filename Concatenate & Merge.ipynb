# %% [markdown]
# # Concatenate

# %%
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.DataFrame({'letter':['a','b'], 'number':[1,2]})
df2 = pd.DataFrame({'letter':['c','d'], 'number':[3,4]})
df3 = pd.DataFrame({'letter':['c','d'], 'number':[3,4], 'animal':['cat', 'dog']})

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
pd.concat([df1, df3], sort=True)
# Out:
#   animal letter  number
# 0    NaN      a       1
# 1    NaN      b       2
# 0    cat      c       3
# 1    dog      d       4

# %%
pd.concat([df1, df3], join="inner") #merge columns that exist in both dataframes
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
cwd = os.getcwd()

dfile = cwd + '/data_source/starbucks-menu-nutrition-drinks.csv'
ffile = cwd + '/data_source/starbucks-menu-nutrition-food.csv'

drinks = pd.read_csv(dfile)
food = pd.read_csv(ffile)

# %%
drinks.head()
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein (g) Sodium
# 0        11         0           0     10
# 1         -         -           -      -
# 2         -         -           -      -
# 3        18         1           0     10
# 4        14         1           0     10

# %%
food.head()
# Out:
#          Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7
# 4  Banana Nut Bread        420      22.0          52           2             6

# %%
pd.concat([drinks, food], sort=True)
# Out:
#       Calories   Carb. (g)   Fat (g)   Fiber (g)   Protein (g) Calories  \
# 0          NaN         NaN       NaN         NaN           NaN       45
# 1          NaN         NaN       NaN         NaN           NaN        -
# 2          NaN         NaN       NaN         NaN           NaN        -
# 3          NaN         NaN       NaN         NaN           NaN       80
# 4          NaN         NaN       NaN         NaN           NaN       60
# 5          NaN         NaN       NaN         NaN           NaN        -
# 6          NaN         NaN       NaN         NaN           NaN        -
# 7          NaN         NaN       NaN         NaN           NaN        -
# 8          NaN         NaN       NaN         NaN           NaN      110
# 9          NaN         NaN       NaN         NaN           NaN        0
# 10         NaN         NaN       NaN         NaN           NaN        -
# 11         NaN         NaN       NaN         NaN           NaN      130
# ...

# %%
pd.concat([drinks, food], join="inner")
# Out:
#                                             Unnamed: 0
# 0             Cool Lime Starbucks Refreshers™ Beverage
# 1                                     Ombré Pink Drink
# 2                                           Pink Drink
# 3       Strawberry Acai Starbucks Refreshers™ Beverage
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...
# 5                                         Violet Drink
# 6      Evolution Fresh™ Cold-Pressed Apple Berry Juice
# 7                          Evolution Fresh™ Defense Up
# 8              Evolution Fresh™ Organic Ginger Limeade
# 9                                          Iced Coffee
# 10                               Iced Coffee with Milk
# 11              Iced Espresso Classics - Vanilla Latte
# 12                Iced Espresso Classics - Caffe Mocha
# 13          Iced Espresso Classics - Caramel Macchiato
# 14                      Starbucks® Caramel Iced Coffee
# 15                       Starbucks® Iced Coffee + Milk
# ...

# %%
#Change column names

food.columns = ['Item', 'Calories' ,'Fat', 'Carb', 'Fiber', 'Protein']
drinks.columns = ['Item', 'Calories' ,'Fat', 'Carb', 'Fiber', 'Protein', 'Na']

# %%
pd.concat([drinks, food], join="inner").head()
# Out:
#                                                 Item Calories Fat Carb Fiber  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45   0   11     0
# 1                                   Ombré Pink Drink        -   -    -     -
# 2                                         Pink Drink        -   -    -     -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80   0   18     1
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60   0   14     1
#
#   Protein
# 0       0
# 1       -
# 2       -
# 3       0
# 4       0

# %%
pd.concat([drinks, food], sort=True).head()
# Out:
#   Calories Carb Fat Fiber                                               Item  \
# 0       45   11   0     0           Cool Lime Starbucks Refreshers™ Beverage
# 1        -    -   -     -                                   Ombré Pink Drink
# 2        -    -   -     -                                         Pink Drink
# 3       80   18   0     1     Strawberry Acai Starbucks Refreshers™ Beverage
# 4       60   14   0     1  Very Berry Hibiscus Starbucks Refreshers™ Beve...
#
#    Na Protein
# 0  10       0
# 1   -       -
# 2   -       -
# 3  10       0
# 4  10       0

# %% [markdown]
# # Merge
